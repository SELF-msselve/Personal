# %%
# Este es el que funciona.
# pip install --proxy 10.236.132.4 ipython ipykernel
# pip install --proxy 10.236.132.4 openpyxl
#
import pandas as pd
import email, smtplib, ssl
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

df = pd.read_excel('SendMail.xlsx')

for index, row in df.iterrows():
    
    sender_email = row['From']
    receiver_email = row['To']
    subject = row['Subject']
    body = row['Body']
    password = 'pjtu jtpw ngad tgbp'
    
    # Create a multipart message and set headers
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = subject
    message["Bcc"] = receiver_email  # Recommended for mass emails

    # Add body to email
    message.attach(MIMEText(body, "plain"))

    filename = row['FileName']  # In same directory as script

    # Open PDF file in binary mode
    with open(filename, "rb") as attachment:
        # Add file as application/octet-stream
        # Email client can usually download this automatically as attachment
        part = MIMEBase("application", "octet-stream")
        part.set_payload(attachment.read())

# Encode file in ASCII characters to send by email    
    encoders.encode_base64(part)

# Add header as key/value pair to attachment part
    part.add_header("Content-Disposition",f"attachment; filename= {filename}")

# Add attachment to message and convert message to string
    message.attach(part)
    text = message.as_string()

# Log in to server using secure context and send email
    context = ssl.create_default_context()
    with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, text)
    
print('Se enviaron todos los correos')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[2], line 53
#      51 # Log in to server using secure context and send email
#      52     context = ssl.create_default_context()
# ---> 53     with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
#      54         server.login(sender_email, password)
#      55         server.sendmail(sender_email, receiver_email, text)
#
# File ~\Documents\py3-12-3\Lib\smtplib.py:1022, in SMTP_SSL.__init__(self, host, port, local_hostname, timeout, source_address, context)
#    1020     context = ssl._create_stdlib_context()
#    1021 self.context = context
# -> 1022 SMTP.__init__(self, host, port, local_hostname, timeout,
#    1023               source_address)
#
# File ~\Documents\py3-12-3\Lib\smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
# ...

# %%
import smtplib
from email.mime.text import MIMEText

subject = "Email Subject"
body = "This is the body of the text message"
sender = "msselve@gmail.com"
recipients = ["msselve@me.com", "eduardo.farina@ypf.com"]
password = "ihhf ekoe zuop tqwv"


def send_email(subject, body, sender, recipients, password):
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
       smtp_server.login(sender, password)
       smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")


send_email(subject, body, sender, recipients, password)
# Out:
# Message sent!

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "msselve@gmail.com"  # Enter your address
receiver_email = "msselve@me.com"  # Enter receiver address
password = 'ihhf ekoe zuop tqwv'
#password = input("Type your password and press enter: ")
message = """\
Subject: Hi there Second type of mail

This message is sent from Python."""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)

# %%
import email, smtplib, ssl

from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

subject = "An email with attachment from Python"
body = "This is an email with attachment sent from Python"
sender_email = "msselve@gmail.com"
receiver_email = "msselve@me.com"
#password = input("Type your password and press enter:")
password = 'ihhf ekoe zuop tqwv'


# Create a multipart message and set headers
message = MIMEMultipart()
message["From"] = sender_email
message["To"] = receiver_email
message["Subject"] = subject
message["Bcc"] = receiver_email  # Recommended for mass emails

# Add body to email
message.attach(MIMEText(body, "plain"))

filename = '202401-Expensas Suipacha 211.pdf'  # In same directory as script

# Open PDF file in binary mode
with open(filename, "rb") as attachment:
    # Add file as application/octet-stream
    # Email client can usually download this automatically as attachment
    part = MIMEBase("application", "octet-stream")
    part.set_payload(attachment.read())

# Encode file in ASCII characters to send by email    
encoders.encode_base64(part)

# Add header as key/value pair to attachment part
part.add_header(
    "Content-Disposition",
    f"attachment; filename= {filename}",
)

# Add attachment to message and convert message to string
message.attach(part)
text = message.as_string()

# Log in to server using secure context and send email
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, text)
